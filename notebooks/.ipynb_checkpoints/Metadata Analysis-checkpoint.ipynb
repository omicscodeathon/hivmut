# %% [markdown]
# ## Importing the Necessary Libraries

# %%
import re
import pandas as pd
import numpy as np
import warnings

warnings.filterwarnings("ignore")

pd.set_option("display.max_columns", None)

# %% [markdown]
# ## Loading the Metadata File and Exploring it

# %%
major_df = pd.read_csv("../data/metadata.csv")

# %%
major_df.head()
# Out:
#    #  SE id(SA) Accession   GI number     Version   Se ID  Sequence Length  \
# 0  1     795536  MF990522  1246707969  MF990522.1  795536             2470
# 1  2     795537  MF990521  1246707968  MF990521.1  795537             2135
# 2  3     795538  MF990520  1246707967  MF990520.1  795538             2556
# 3  4     795539  MF990519  1246707966  MF990519.1  795539             2589
# 4  5     795540  MF990518  1246707965  MF990518.1  795540             2547
#
#                                           GB comment GB create date  \
# 0  GenBank staff is unable to verify sequence and...     2017-10-01
# 1  GenBank staff is unable to verify sequence and...     2017-10-01
# 2  GenBank staff is unable to verify sequence and...     2017-10-01
# 3  GenBank staff is unable to verify sequence and...     2017-10-01
# 4  GenBank staff is unable to verify sequence and...     2017-10-01
#
#   GB update date  Percent non-ACGT  SE id(SSAM)  PAT id(SSAM)     Name  \
# ...

# %%
remaining_metadata_df = pd.read_csv(
    "../data/processed/output_fragments/Advanced_results_NoSEQ.txt",
    sep="\t",
    index_col=False,
)
remaining_metadata_df.head()
# Out:
#    #  SE id(SSAM)  PAT id(SSAM)   Name       Country  Sampling Year Subtype  \
# 0  1      1067058      154330.0  M339A  SOUTH AFRICA           2014       C
# 1  2      1067059      154669.0  M338A        UGANDA           2014       D
# 2  3      1067060      154715.0  M337A        UGANDA           2014      A1
# 3  4      1067061      153839.0  M336A        UGANDA           2014     A1D
# 4  5      1067062      153945.0  M335A        UGANDA           2013      A1
#
#    Days from Infection  Days from Seroconversion RIP subtype    Se ID  \
# 0                  NaN                       NaN           C  1067058
# 1                  NaN                       NaN           D  1067059
# 2                  NaN                       NaN          A1  1067060
# 3                  NaN                       NaN         A1D  1067061
# 4                  NaN                       NaN          A1  1067062
#
#    Sequence Length  Patient Id Patient Sex   Risk Factor  Infection Year  \
# ...

# %%
df = pd.concat([major_df, remaining_metadata_df], join="outer", ignore_index=True)
df
# Out:
#            #  SE id(SA) Accession     GI number     Version    Se ID  \
# 0          1     795536  MF990522  1.246708e+09  MF990522.1   795536
# 1          2     795537  MF990521  1.246708e+09  MF990521.1   795537
# 2          3     795538  MF990520  1.246708e+09  MF990520.1   795538
# 3          4     795539  MF990519  1.246708e+09  MF990519.1   795539
# 4          5     795540  MF990518  1.246708e+09  MF990518.1   795540
# ...      ...        ...       ...           ...         ...      ...
# 233222  1996    1182836  MZ766586           NaN         NaN  1182836
# 233223  1997    1182837  MZ766585           NaN         NaN  1182837
# 233224  1998    1182838  MZ766584           NaN         NaN  1182838
# 233225  1999    1182839  MZ766583           NaN         NaN  1182839
# 233226  2000    1182840  MZ766582           NaN         NaN  1182840
#
#         Sequence Length                                         GB comment  \
# ...

# %%
df.columns
# Out:
# Index(['#', 'SE id(SA)', 'Accession', 'GI number', 'Version', 'Se ID',
#        'Sequence Length', 'GB comment', 'GB create date', 'GB update date',
#        'Percent non-ACGT', 'SE id(SSAM)', 'PAT id(SSAM)', 'Name', 'Locus Name',
#        'Isolate Name', 'Clone Name', 'Georegion', 'Country', 'Sampling City',
#        'Sampling Year', 'Sampling Year Upper', 'Patient Age', 'Patient Health',
#        'Organism', 'Subtype', 'Phenotype', 'Coreceptor', 'Sample Tissue',
#        'Culture Method', 'Molecule type', 'Drug Naive', 'Problematic Sequence',
#        'Viral load', 'CD4 count', 'CD8 count', 'Days from Infection',
#        'Days from Seroconversion', 'Days from first Sample',
#        'Sequencing method', 'Amplification strategy', 'Fiebig Stage', 'Anno',
#        'Days from treatment start', 'Days from treatment end',
#        'Vaccine status', 'RIP subtype', 'Patient Id', 'Patient Sex',
#        'Risk Factor', 'Infection Year'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 233227 entries, 0 to 233226
# Data columns (total 51 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   #                          233227 non-null  int64
#  1   SE id(SA)                  233227 non-null  int64
#  2   Accession                  233227 non-null  object
#  3   GI number                  231227 non-null  float64
#  4   Version                    231227 non-null  object
#  5   Se ID                      233227 non-null  int64
#  6   Sequence Length            233227 non-null  int64
#  7   GB comment                 136566 non-null  object
#  8   GB create date             231227 non-null  object
#  9   GB update date             231227 non-null  object
#  10  Percent non-ACGT           231227 non-null  float64
#  11  SE id(SSAM)                233227 non-null  int64
#  12  PAT id(SSAM)               172701 non-null  float64
# ...

# %% [markdown]
# ## Optimising the DataFrame to reduce memory usage

# %%
# Downcast numeric types to the most efficient representation
for col in df.select_dtypes(include=["float"]):
    df[col] = pd.to_numeric(df[col], downcast="float")

for col in df.select_dtypes(include=["int"]):
    df[col] = pd.to_numeric(df[col], downcast="integer")

# Convert object types to category if they have few unique values
for col in df.select_dtypes(include=["object"]).columns:
    unique_values = df[col].nunique()
    total_values = len(df[col])
    if unique_values / total_values < 0.5:  # If more than 50% of values are repetitive
        df[col] = df[col].astype("category")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 233227 entries, 0 to 233226
# Data columns (total 51 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   #                          233227 non-null  int16
#  1   SE id(SA)                  233227 non-null  int32
#  2   Accession                  233227 non-null  object
#  3   GI number                  231227 non-null  float64
#  4   Version                    231227 non-null  object
#  5   Se ID                      233227 non-null  int32
#  6   Sequence Length            233227 non-null  int16
#  7   GB comment                 136566 non-null  category
#  8   GB create date             231227 non-null  category
#  9   GB update date             231227 non-null  category
#  10  Percent non-ACGT           231227 non-null  float32
#  11  SE id(SSAM)                233227 non-null  int32
#  12  PAT id(SSAM)               172701 non-null  float32
# ...

# %%
df.describe()
# Out:
#                    #     SE id(SA)     GI number         Se ID  \
# count  233227.000000  2.332270e+05  2.312270e+05  2.332270e+05
# mean     7407.741719  5.869033e+05  8.359108e+08  5.869033e+05
# std      4746.315790  3.311082e+05  7.511699e+08  3.311082e+05
# min         1.000000  2.810000e+02  6.023800e+04  2.810000e+02
# 25%      3022.000000  3.600235e+05  3.002453e+08  3.600235e+05
# 50%      7187.000000  5.365440e+05  4.622114e+08  5.365440e+05
# 75%     11515.000000  8.258015e+05  1.341082e+09  8.258015e+05
# max     16000.000000  1.285059e+06  2.783937e+09  1.285059e+06
#
#        Sequence Length  Percent non-ACGT   SE id(SSAM)   PAT id(SSAM)  \
# count    233227.000000     231227.000000  2.332270e+05  172701.000000
# mean       1433.876271          0.292750  5.869033e+05   63430.199219
# std        1501.301278          0.640116  3.311082e+05   41730.769531
# min          55.000000          0.000000  2.810000e+02       5.000000
# ...

# %%
df.describe(include="object")
# Out:
#        Accession     Version    Name Locus Name Isolate Name
# count     233227      231227  233226     231227       219408
# unique    217227      215227  181690     215227       168107
# top     HQ702687  HQ596176.1   HS507   HQ596176           B1
# freq           2           2     191          2          351

# %%
df.describe(include="category")
# Out:
#                                                GB comment GB create date  \
# count                                              136566         231227
# unique                                              25809           1278
# top     ##Assembly-Data-START## ; Sequencing Technolog...     2011-03-08
# freq                                                22367           5956
#
#        GB update date Clone Name Georegion       Country Sampling City  \
# count          231227      22546    231227        233227         92989
# unique           1232      12264         2            49           595
# top        2011-03-08          2   AFR SSA  SOUTH AFRICA         RAKAI
# freq             5952        410    227265         45411          7929
#
#        Patient Age Patient Health Organism Subtype Phenotype Coreceptor  \
# count        49480          15853   231227  230458       903       3405
# unique        1210              6        1     263         3         12
# ...

# %%
# Drop Duplicate Entries in the Dataset
df.drop_duplicates().reset_index().head(2)
# Out:
#    index  #  SE id(SA) Accession     GI number     Version   Se ID  \
# 0      0  1     795536  MF990522  1.246708e+09  MF990522.1  795536
# 1      1  2     795537  MF990521  1.246708e+09  MF990521.1  795537
#
#    Sequence Length                                         GB comment  \
# 0             2470  GenBank staff is unable to verify sequence and...
# 1             2135  GenBank staff is unable to verify sequence and...
#
#   GB create date GB update date  Percent non-ACGT  SE id(SSAM)  PAT id(SSAM)  \
# 0     2017-10-01     2017-10-01               0.3       795536           NaN
# 1     2017-10-01     2017-10-01               1.7       795537           NaN
#
#       Name Locus Name Isolate Name Clone Name Georegion       Country  \
# 0  FOST145   MF990522      FOST145        NaN   AFR SSA  SOUTH AFRICA
# 1  FOST144   MF990521      FOST144        NaN   AFR SSA  SOUTH AFRICA
#
#   Sampling City  Sampling Year  Sampling Year Upper Patient Age  \
# ...

# %% [markdown]
# ##  Further CrossMatching with the Validation and Gene Info Data

# %%
validation_path = "../data/csv_output/validation_results.csv"
validation_df = pd.read_csv(validation_path)

# %%
validation_df.head()
# Out:
#   Input Sequence     Level                                            Message
# 0       HQ172324  CRITICAL  There were no PR, RT, and IN genes found, refu...
# 1       EF203958  CRITICAL  There were no PR, RT, and IN genes found, refu...
# 2       KF374017  CRITICAL  There were no PR, RT, and IN genes found, refu...
# 3       KC422797      NOTE  303 positions were not sequenced or aligned: R...
# 4       FJ931208   WARNING  225 positions were not sequenced or aligned: R...

# %%
def extract_and_convert(message):
    # Regex to detect missing genes (e.g., PR, RT, IN)
    missing_genes = list(set(re.findall(r"\bPR\b|\bRT\b|\bIN\b", message)))

    # Regex to detect drug resistance positions
    resistance_positions = list(set(re.findall(r"RT\s\d+", message)))

    # Look for specific issues (frameshift, missing sequences, etc.)
    issues = []
    if "frameshift" in message.lower():
        issues.append("frameshift")
    if "refuse to process" in message.lower():
        issues.append("refuse to process")
    if "not sequenced or aligned" in message.lower():
        issues.append("missing sequence")

    # Convert lists to comma-separated strings or NaN for empty lists
    missing_genes_str = ", ".join(missing_genes) if missing_genes else np.nan
    resistance_positions_str = (
        ", ".join(resistance_positions) if resistance_positions else np.nan
    )
    issues_str = ", ".join(issues) if issues else np.nan

    return pd.Series([missing_genes_str, resistance_positions_str, issues_str])


# Apply the combined function and expand the results into new columns
validation_df[["Missing Genes", "Drug Resistance Positions", "Issues"]] = validation_df[
    "Message"
].apply(extract_and_convert)

# Display the extracted info
validation_df.head()
# Out:
#   Input Sequence     Level                                            Message  \
# 0       HQ172324  CRITICAL  There were no PR, RT, and IN genes found, refu...
# 1       EF203958  CRITICAL  There were no PR, RT, and IN genes found, refu...
# 2       KF374017  CRITICAL  There were no PR, RT, and IN genes found, refu...
# 3       KC422797      NOTE  303 positions were not sequenced or aligned: R...
# 4       FJ931208   WARNING  225 positions were not sequenced or aligned: R...
#
#   Missing Genes Drug Resistance Positions             Issues
# 0    IN, PR, RT                       NaN  refuse to process
# 1    IN, PR, RT                       NaN  refuse to process
# 2    IN, PR, RT                       NaN  refuse to process
# 3            RT            RT 258, RT 318   missing sequence
# 4            RT            RT 348, RT 336   missing sequence

# %%
len(validation_df[validation_df["Level"] != "CRITICAL"]["Input Sequence"].unique())
# Out:
# 98307

# %%
gene_info_path = "../data/csv_output/gene_info.csv"
gene_info_df = pd.read_csv(gene_info_path)
gene_info_df.head()
# Out:
#   Input Sequence Strain Name           Subtype Gene Name  First AA  Last AA  \
# 0       KC422797        HIV1         C (3.09%)        PR         1       99
# 1       KC422797        HIV1         C (3.09%)        RT         1      257
# 2       FJ931208        HIV1  CRF02_AG (4.61%)        PR         1       99
# 3       FJ931208        HIV1  CRF02_AG (4.61%)        RT         1      335
# 4       KT982514        HIV1         C (5.08%)        RT        38      247
#
#    Gene Length
# 0           99
# 1          560
# 2           99
# 3          560
# 4          560

# %%
len(gene_info_df["Input Sequence"].unique())
# Out:
# 113301

# %%
drug_resistance_path = "../data/csv_output/drug_resistance_mutations.csv"
drug_resistance_df = pd.read_csv(drug_resistance_path)
drug_resistance_df
# Out:
#        Input Sequence Gene Name Drug Class Drug Drug Full Name  Score  Level  \
# 0            KC422797        RT       NRTI  ABC            ABC   10.0      2
# 1            KC422797        RT       NRTI  AZT            AZT   60.0      5
# 2            KC422797        RT       NRTI  D4T            D4T   40.0      4
# 3            KC422797        RT       NRTI  DDI            DDI   15.0      3
# 4            KC422797        RT       NRTI  TDF            TDF   10.0      2
# ...               ...       ...        ...  ...            ...    ...    ...
# 899463       MF797082        RT       NRTI  FTC            FTC   60.0      5
# 899464       MF797082        RT       NRTI  3TC            LMV   60.0      5
# 899465       MF797082        RT       NRTI  TDF            TDF  -10.0      1
# 899466       MF797082        RT      NNRTI  EFV            EFV   60.0      5
# 899467       MF797082        RT      NNRTI  NVP            NVP   60.0      5
#
#        Mutation Text Mutation Primary Type
# ...

# %%
mutations_path = "../data/csv_output/general_mutations.csv"
mutations_df = pd.read_csv(mutations_path)
mutations_df
# Out:
#         Input Sequence Strain Name           Subtype Gene Name  \
# 0             KC422797        HIV1         C (3.09%)        PR
# 1             KC422797        HIV1         C (3.09%)        PR
# 2             KC422797        HIV1         C (3.09%)        PR
# 3             KC422797        HIV1         C (3.09%)        PR
# 4             KC422797        HIV1         C (3.09%)        PR
# ...                ...         ...               ...       ...
# 3224204       MF797083        HIV1  CRF02_AG (4.92%)        RT
# 3224205       MF797083        HIV1  CRF02_AG (4.92%)        RT
# 3224206       MF797083        HIV1  CRF02_AG (4.92%)        RT
# 3224207       MF797083        HIV1  CRF02_AG (4.92%)        RT
# 3224208       MF797083        HIV1  CRF02_AG (4.92%)        RT
#
#          Mutation Position Amino Acids Primary Type Consensus  Is Insertion  \
# 0                       12           S        Other         T         False
# ...

# %%
len(mutations_df["Input Sequence"].unique())
# Out:
# 113299
